# %%
import pandas as pd

# %%
menu_items_1 = [
    {
        "name": "Margherita Pizza",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Dough", "Tomato Sauce", "Mozzarella", "Basil"],
        "serving": "1 slice",
        "price": 12.00,
        "calories": 250
    },
    {
        "name": "Chicken Caesar Salad",
        "cuisine": "American",
        "type": "Salad",
        "ingredients": ["Romaine Lettuce", "Grilled Chicken", "Dressing"],
        "serving": "1 bowl",
        "price": 10.50,
        "calories": 400
    },
    {
        "name": "Pad Thai",
        "cuisine": "Thai",
        "type": "Main Dish",
        "ingredients": ["Rice Noodles", "Shrimp", "Peanuts", "Bean Sprouts"],
        "serving": "1 plate",
        "price": 14.00,
        "calories": 600
    },
    {
        "name": "Sushi Roll (California)",
        "cuisine": "Japanese",
        "type": "Appetizer",
        "ingredients": ["Sushi Rice", "Nori", "Crab", "Avocado", "Cucumber"],
        "serving": "8 pieces",
        "price": 9.00,
        "calories": 300
    },
    {
        "name": "Cheeseburger",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Ground Beef", "Cheddar", "Lettuce", "Tomato", "Bun"],
        "serving": "1 burger",
        "price": 11.00,
        "calories": 450
    },
    {
        "name": "Spaghetti Carbonara",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Spaghetti", "Eggs", "Parmesan", "Bacon"],
        "serving": "1 plate",
        "price": 13.50,
        "calories": 550
    },
    {
        "name": "Beef Tacos",
        "cuisine": "Mexican",
        "type": "Main Dish",
        "ingredients": ["Beef", "Tortilla", "Salsa", "Cheese"],
        "serving": "3 tacos",
        "price": 8.00,
        "calories": 400
    },
    {
        "name": "Greek Salad",
        "cuisine": "Mediterranean",
        "type": "Salad",
        "ingredients": ["Cucumber", "Feta", "Olives", "Red Onion"],
        "serving": "1 bowl",
        "price": 7.00,
        "calories": 320
    },
    {
        "name": "BBQ Chicken Pizza",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Dough", "BBQ Sauce", "Chicken", "Cheese"],
        "serving": "1 slice",
        "price": 13.00,
        "calories": 300
    },
    {
        "name": "Egg Fried Rice",
        "cuisine": "Chinese",
        "type": "Main Dish",
        "ingredients": ["Rice", "Egg", "Soy Sauce", "Peas"],
        "serving": "1 plate",
        "price": 9.50,
        "calories": 450
    },
    {
        "name": "French Onion Soup",
        "cuisine": "French",
        "type": "Soup",
        "ingredients": ["Onions", "Beef Broth", "Gruyère Cheese"],
        "serving": "1 bowl",
        "price": 7.50,
        "calories": 200
    },
    {
        "name": "Butter Chicken",
        "cuisine": "Indian",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Cream", "Tomato Sauce", "Spices"],
        "serving": "1 plate",
        "price": 15.00,
        "calories": 550
    },
    {
        "name": "Fish and Chips",
        "cuisine": "British",
        "type": "Main Dish",
        "ingredients": ["Cod", "Potatoes", "Tartar Sauce"],
        "serving": "1 serving",
        "price": 14.00,
        "calories": 600
    },
    {
        "name": "Veggie Burger",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Veggie Patty", "Lettuce", "Tomato", "Bun"],
        "serving": "1 burger",
        "price": 9.50,
        "calories": 350
    },
    {
        "name": "Chicken Biryani",
        "cuisine": "Indian",
        "type": "Main Dish",
        "ingredients": ["Rice", "Chicken", "Spices"],
        "serving": "1 plate",
        "price": 12.50,
        "calories": 700
    },
    {
        "name": "Falafel Wrap",
        "cuisine": "Middle Eastern",
        "type": "Main Dish",
        "ingredients": ["Falafel", "Pita", "Hummus", "Lettuce", "Tomato"],
        "serving": "1 wrap",
        "price": 8.50,
        "calories": 350
    },
    {
        "name": "Shrimp Scampi",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Shrimp", "Garlic", "Butter", "Pasta"],
        "serving": "1 plate",
        "price": 16.00,
        "calories": 600
    },
    {
        "name": "Lobster Roll",
        "cuisine": "American",
        "type": "Sandwich",
        "ingredients": ["Lobster", "Butter", "Hot Dog Bun"],
        "serving": "1 roll",
        "price": 18.00,
        "calories": 450
    },
    {
        "name": "Chocolate Lava Cake",
        "cuisine": "Dessert",
        "type": "Dessert",
        "ingredients": ["Chocolate", "Butter", "Sugar", "Flour", "Eggs"],
        "serving": "1 cake",
        "price": 7.00,
        "calories": 500
    },
    {
        "name": "Chicken Alfredo Pasta",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Pasta", "Chicken", "Cream Sauce"],
        "serving": "1 plate",
        "price": 12.00,
        "calories": 700
    },
    {
        "name": "Steak Frites",
        "cuisine": "French",
        "type": "Main Dish",
        "ingredients": ["Steak", "French Fries"],
        "serving": "1 serving",
        "price": 18.00,
        "calories": 800
    },
    {
        "name": "Vegetable Stir-Fry",
        "cuisine": "Chinese",
        "type": "Main Dish",
        "ingredients": ["Mixed Vegetables", "Soy Sauce"],
        "serving": "1 plate",
        "price": 9.00,
        "calories": 350
    },
    {
        "name": "Tom Yum Soup",
        "cuisine": "Thai",
        "type": "Soup",
        "ingredients": ["Shrimp", "Lemongrass", "Chili"],
        "serving": "1 bowl",
        "price": 11.00,
        "calories": 200
    },
    {
        "name": "Avocado Toast",
        "cuisine": "American",
        "type": "Breakfast",
        "ingredients": ["Avocado", "Toast"],
        "serving": "1 slice",
        "price": 7.50,
        "calories": 250
    },
    {
        "name": "Ramen Noodles",
        "cuisine": "Japanese",
        "type": "Main Dish",
        "ingredients": ["Noodles", "Pork", "Broth"],
        "serving": "1 bowl",
        "price": 12.00,
        "calories": 550
    },
    {
        "name": "Pulled Pork Sandwich",
        "cuisine": "American",
        "type": "Sandwich",
        "ingredients": ["Pulled Pork", "BBQ Sauce", "Bun"],
        "serving": "1 sandwich",
        "price": 10.00,
        "calories": 600
    },
    {
        "name": "Miso Soup",
        "cuisine": "Japanese",
        "type": "Soup",
        "ingredients": ["Miso Paste", "Tofu", "Seaweed"],
        "serving": "1 bowl",
        "price": 5.00,
        "calories": 100
    },
    {
        "name": "Pho",
        "cuisine": "Vietnamese",
        "type": "Soup",
        "ingredients": ["Rice Noodles", "Beef", "Broth"],
        "serving": "1 bowl",
        "price": 12.00,
        "calories": 450
    },
    {
        "name": "Eggplant Parmesan",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Eggplant", "Tomato Sauce", "Mozzarella"],
        "serving": "1 plate",
        "price": 11.50,
        "calories": 500
    },
    {
        "name": "Peking Duck",
        "cuisine": "Chinese",
        "type": "Main Dish",
        "ingredients": ["Duck", "Pancakes", "Hoisin Sauce"],
        "serving": "1 plate",
        "price": 25.00,
        "calories": 850
    },
    {
        "name": "Buffalo Wings",
        "cuisine": "American",
        "type": "Appetizer",
        "ingredients": ["Chicken Wings", "Buffalo Sauce"],
        "serving": "6 pieces",
        "price": 9.00,
        "calories": 600
    },
    {
        "name": "Spring Rolls",
        "cuisine": "Vietnamese",
        "type": "Appetizer",
        "ingredients": ["Rice Paper", "Shrimp", "Vegetables"],
        "serving": "4 rolls",
        "price": 7.50,
        "calories": 250
    },
    {
        "name": "Grilled Salmon",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Salmon", "Lemon", "Herbs"],
        "serving": "1 fillet",
        "price": 16.00,
        "calories": 400
    },
    {
        "name": "Vegetarian Lasagna",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Lasagna Noodles", "Ricotta", "Spinach", "Tomato Sauce"],
        "serving": "1 plate",
        "price": 13.00,
        "calories": 550
    },
    {
        "name": "Chicken Quesadilla",
        "cuisine": "Mexican",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Cheese", "Tortilla"],
        "serving": "1 serving",
        "price": 8.50,
        "calories": 450
    },
    {
        "name": "Tuna Sashimi",
        "cuisine": "Japanese",
        "type": "Appetizer",
        "ingredients": ["Tuna", "Soy Sauce"],
        "serving": "6 pieces",
        "price": 14.00,
        "calories": 300
    },
    {
        "name": "Shakshuka",
        "cuisine": "Middle Eastern",
        "type": "Breakfast",
        "ingredients": ["Eggs", "Tomato Sauce", "Peppers"],
        "serving": "1 pan",
        "price": 10.00,
        "calories": 350
    },
    {
        "name": "Burrito",
        "cuisine": "Mexican",
        "type": "Main Dish",
        "ingredients": ["Rice", "Beans", "Chicken", "Salsa"],
        "serving": "1 burrito",
        "price": 8.50,
        "calories": 700
    },
    {
        "name": "Dim Sum",
        "cuisine": "Chinese",
        "type": "Appetizer",
        "ingredients": ["Dumplings", "Pork", "Shrimp"],
        "serving": "6 pieces",
        "price": 12.00,
        "calories": 300
    },
    {
        "name": "Cauliflower Buffalo Bites",
        "cuisine": "American",
        "type": "Appetizer",
        "ingredients": ["Cauliflower", "Buffalo Sauce"],
        "serving": "1 plate",
        "price": 7.50,
        "calories": 250
    },
    {
        "name": "Tiramisu",
        "cuisine": "Italian",
        "type": "Dessert",
        "ingredients": ["Mascarpone", "Espresso", "Ladyfingers"],
        "serving": "1 slice",
        "price": 6.50,
        "calories": 450
    },
    {
        "name": "Kimchi Fried Rice",
        "cuisine": "Korean",
        "type": "Main Dish",
        "ingredients": ["Rice", "Kimchi", "Egg"],
        "serving": "1 plate",
        "price": 9.00,
        "calories": 500
    },
    {
        "name": "Clam Chowder",
        "cuisine": "American",
        "type": "Soup",
        "ingredients": ["Clams", "Potatoes", "Cream"],
        "serving": "1 bowl",
        "price": 8.00,
        "calories": 350
    },
    {
        "name": "Gyro",
        "cuisine": "Greek",
        "type": "Sandwich",
        "ingredients": ["Lamb", "Tzatziki", "Pita"],
        "serving": "1 serving",
        "price": 10.50,
        "calories": 600
    },
    {
        "name": "Baklava",
        "cuisine": "Mediterranean",
        "type": "Dessert",
        "ingredients": ["Phyllo Dough", "Honey", "Walnuts"],
        "serving": "1 slice",
        "price": 5.00,
        "calories": 300
    },
    {
        "name": "Spaghetti Bolognese",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Spaghetti", "Ground Beef", "Tomato Sauce"],
        "serving": "1 plate",
        "price": 13.00,
        "calories": 550
    },
    {
        "name": "Chicken Shawarma",
        "cuisine": "Middle Eastern",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Pita", "Garlic Sauce"],
        "serving": "1 wrap",
        "price": 9.00,
        "calories": 450
    },
    {
        "name": "Mac and Cheese",
        "cuisine": "American",
        "type": "Side Dish",
        "ingredients": ["Macaroni", "Cheese", "Butter"],
        "serving": "1 bowl",
        "price": 6.00,
        "calories": 400
    },
    {
        "name": "Beef Stroganoff",
        "cuisine": "Russian",
        "type": "Main Dish",
        "ingredients": ["Beef", "Mushrooms", "Sour Cream", "Noodles"],
        "serving": "1 plate",
        "price": 14.00,
        "calories": 600
    },
    {
        "name": "Cheese Fondue",
        "cuisine": "Swiss",
        "type": "Appetizer",
        "ingredients": ["Cheese", "Bread"],
        "serving": "1 pot",
        "price": 12.00,
        "calories": 500
    }
]

# %%
menu_items_2 = [
    {
        "name": "Chicken Parmesan",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Tomato Sauce", "Mozzarella"],
        "serving": "1 plate",
        "price": 14.00,
        "calories": 700
    },
    {
        "name": "Margarita",
        "cuisine": "Mexican",
        "type": "Beverage",
        "ingredients": ["Tequila", "Lime Juice", "Triple Sec"],
        "serving": "1 glass",
        "price": 8.00,
        "calories": 200
    },
    {
        "name": "Chocolate Chip Cookies",
        "cuisine": "Dessert",
        "type": "Dessert",
        "ingredients": ["Flour", "Butter", "Chocolate Chips"],
        "serving": "2 cookies",
        "price": 4.00,
        "calories": 300
    },
    {
        "name": "Gnocchi",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Potatoes", "Flour", "Parmesan"],
        "serving": "1 plate",
        "price": 13.00,
        "calories": 500
    },
    {
        "name": "Falafel Salad",
        "cuisine": "Middle Eastern",
        "type": "Salad",
        "ingredients": ["Falafel", "Lettuce", "Tomato", "Hummus"],
        "serving": "1 bowl",
        "price": 8.50,
        "calories": 400
    },
    {
        "name": "Pork Ribs",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Pork Ribs", "BBQ Sauce"],
        "serving": "1 serving",
        "price": 16.00,
        "calories": 700
    },
    {
        "name": "Fish Tacos",
        "cuisine": "Mexican",
        "type": "Main Dish",
        "ingredients": ["Fish", "Tortilla", "Salsa", "Cabbage"],
        "serving": "3 tacos",
        "price": 9.00,
        "calories": 350
    },
    {
        "name": "Crepes",
        "cuisine": "French",
        "type": "Dessert",
        "ingredients": ["Flour", "Eggs", "Milk", "Sugar"],
        "serving": "1 crepe",
        "price": 6.50,
        "calories": 250
    },
    {
        "name": "Moussaka",
        "cuisine": "Greek",
        "type": "Main Dish",
        "ingredients": ["Eggplant", "Ground Beef", "Bechamel"],
        "serving": "1 plate",
        "price": 13.00,
        "calories": 600
    },
    {
        "name": "Chicken Pad See Ew",
        "cuisine": "Thai",
        "type": "Main Dish",
        "ingredients": ["Rice Noodles", "Chicken", "Soy Sauce", "Vegetables"],
        "serving": "1 plate",
        "price": 13.50,
        "calories": 600
    },
    {
        "name": "French Toast",
        "cuisine": "American",
        "type": "Breakfast",
        "ingredients": ["Bread", "Eggs", "Milk", "Cinnamon"],
        "serving": "1 slice",
        "price": 7.00,
        "calories": 300
    },
    {
        "name": "Beef Wellington",
        "cuisine": "British",
        "type": "Main Dish",
        "ingredients": ["Beef", "Puff Pastry", "Mushrooms"],
        "serving": "1 serving",
        "price": 25.00,
        "calories": 800
    },
    {
        "name": "Vegetable Curry",
        "cuisine": "Indian",
        "type": "Main Dish",
        "ingredients": ["Mixed Vegetables", "Curry Sauce", "Rice"],
        "serving": "1 plate",
        "price": 12.00,
        "calories": 500
    },
    {
        "name": "Chicken and Waffles",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Fried Chicken", "Waffles", "Syrup"],
        "serving": "1 serving",
        "price": 15.00,
        "calories": 750
    },
    {
        "name": "Huevos Rancheros",
        "cuisine": "Mexican",
        "type": "Breakfast",
        "ingredients": ["Eggs", "Tortillas", "Salsa"],
        "serving": "1 serving",
        "price": 9.00,
        "calories": 400
    },
    {
        "name": "Spinach and Ricotta Ravioli",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Ravioli", "Spinach", "Ricotta Cheese"],
        "serving": "1 plate",
        "price": 14.00,
        "calories": 550
    },
    {
        "name": "Sweet and Sour Chicken",
        "cuisine": "Chinese",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Bell Peppers", "Pineapple"],
        "serving": "1 plate",
        "price": 11.50,
        "calories": 600
    },
    {
        "name": "Penne Arrabbiata",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Penne", "Tomato Sauce", "Red Chili"],
        "serving": "1 plate",
        "price": 12.00,
        "calories": 500
    },
    {
        "name": "Fettuccine Alfredo",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Fettuccine", "Cream", "Parmesan"],
        "serving": "1 plate",
        "price": 13.00,
        "calories": 700
    },
    {
        "name": "Tofu Stir-Fry",
        "cuisine": "Chinese",
        "type": "Main Dish",
        "ingredients": ["Tofu", "Vegetables", "Soy Sauce"],
        "serving": "1 plate",
        "price": 10.00,
        "calories": 350
    },
    {
        "name": "Tandoori Chicken",
        "cuisine": "Indian",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Yogurt", "Spices"],
        "serving": "1 serving",
        "price": 15.00,
        "calories": 550
    },
    {
        "name": "Churros",
        "cuisine": "Mexican",
        "type": "Dessert",
        "ingredients": ["Flour", "Cinnamon", "Sugar"],
        "serving": "3 pieces",
        "price": 6.00,
        "calories": 300
    },
    {
        "name": "Bruschetta",
        "cuisine": "Italian",
        "type": "Appetizer",
        "ingredients": ["Bread", "Tomatoes", "Basil", "Olive Oil"],
        "serving": "1 serving",
        "price": 7.00,
        "calories": 250
    },
    {
        "name": "Lamb Kofta",
        "cuisine": "Middle Eastern",
        "type": "Main Dish",
        "ingredients": ["Ground Lamb", "Spices", "Pita"],
        "serving": "1 serving",
        "price": 12.50,
        "calories": 550
    },
    {
        "name": "Pumpkin Pie",
        "cuisine": "American",
        "type": "Dessert",
        "ingredients": ["Pumpkin", "Sugar", "Pie Crust"],
        "serving": "1 slice",
        "price": 5.50,
        "calories": 300
    },
    {
        "name": "Crab Cakes",
        "cuisine": "American",
        "type": "Appetizer",
        "ingredients": ["Crab", "Breadcrumbs", "Spices"],
        "serving": "2 cakes",
        "price": 13.00,
        "calories": 400
    },
    {
        "name": "Beef Pho",
        "cuisine": "Vietnamese",
        "type": "Soup",
        "ingredients": ["Rice Noodles", "Beef", "Herbs"],
        "serving": "1 bowl",
        "price": 12.00,
        "calories": 450
    },
    {
        "name": "Egg Drop Soup",
        "cuisine": "Chinese",
        "type": "Soup",
        "ingredients": ["Egg", "Chicken Broth", "Cornstarch"],
        "serving": "1 bowl",
        "price": 6.00,
        "calories": 150
    },
    {
        "name": "Caprese Salad",
        "cuisine": "Italian",
        "type": "Salad",
        "ingredients": ["Tomatoes", "Mozzarella", "Basil", "Olive Oil"],
        "serving": "1 plate",
        "price": 8.50,
        "calories": 300
    },
    {
        "name": "French Crepe with Nutella",
        "cuisine": "French",
        "type": "Dessert",
        "ingredients": ["Crepe", "Nutella"],
        "serving": "1 crepe",
        "price": 6.00,
        "calories": 350
    },
    {
        "name": "Seafood Paella",
        "cuisine": "Spanish",
        "type": "Main Dish",
        "ingredients": ["Rice", "Shrimp", "Mussels", "Saffron"],
        "serving": "1 plate",
        "price": 18.00,
        "calories": 700
    },
    {
        "name": "Lamb Curry",
        "cuisine": "Indian",
        "type": "Main Dish",
        "ingredients": ["Lamb", "Curry Sauce", "Rice"],
        "serving": "1 plate",
        "price": 15.00,
        "calories": 700
    },
    {
        "name": "Cobb Salad",
        "cuisine": "American",
        "type": "Salad",
        "ingredients": ["Lettuce", "Bacon", "Avocado", "Egg", "Blue Cheese"],
        "serving": "1 bowl",
        "price": 10.50,
        "calories": 500
    },
    {
        "name": "Beef Burrito Bowl",
        "cuisine": "Mexican",
        "type": "Main Dish",
        "ingredients": ["Rice", "Beef", "Beans", "Salsa"],
        "serving": "1 bowl",
        "price": 9.50,
        "calories": 600
    },
    {
        "name": "Roast Chicken",
        "cuisine": "American",
        "type": "Main Dish",
        "ingredients": ["Chicken", "Herbs", "Potatoes"],
        "serving": "1 serving",
        "price": 14.00,
        "calories": 550
    },
    {
        "name": "Quiche Lorraine",
        "cuisine": "French",
        "type": "Main Dish",
        "ingredients": ["Eggs", "Bacon", "Cheese", "Pastry"],
        "serving": "1 slice",
        "price": 7.50,
        "calories": 350
    },
    {
        "name": "Lamb Shawarma",
        "cuisine": "Middle Eastern",
        "type": "Main Dish",
        "ingredients": ["Lamb", "Pita", "Vegetables", "Garlic Sauce"],
        "serving": "1 serving",
        "price": 12.00,
        "calories": 600
    },
    {
        "name": "Chocolate Mousse",
        "cuisine": "French",
        "type": "Dessert",
        "ingredients": ["Chocolate", "Cream", "Sugar"],
        "serving": "1 serving",
        "price": 6.50,
        "calories": 400
    },
    {
        "name": "Grilled Cheese Sandwich",
        "cuisine": "American",
        "type": "Sandwich",
        "ingredients": ["Bread", "Cheese", "Butter"],
        "serving": "1 sandwich",
        "price": 5.00,
        "calories": 400
    },
    {
        "name": "Stuffed Peppers",
        "cuisine": "Mediterranean",
        "type": "Main Dish",
        "ingredients": ["Bell Peppers", "Rice", "Ground Meat"],
        "serving": "1 serving",
        "price": 10.00,
        "calories": 500
    },
    {
        "name": "Shrimp Tacos",
        "cuisine": "Mexican",
        "type": "Main Dish",
        "ingredients": ["Shrimp", "Tortillas", "Salsa", "Cabbage"],
        "serving": "3 tacos",
        "price": 9.50,
        "calories": 350
    },
    {
        "name": "Chicken Satay",
        "cuisine": "Thai",
        "type": "Appetizer",
        "ingredients": ["Chicken", "Peanut Sauce"],
        "serving": "1 serving",
        "price": 8.00,
        "calories": 300
    },
    {
        "name": "Pork Dumplings",
        "cuisine": "Chinese",
        "type": "Appetizer",
        "ingredients": ["Pork", "Dumpling Wrappers", "Soy Sauce"],
        "serving": "6 pieces",
        "price": 7.50,
        "calories": 250
    },
    {
        "name": "Cheesecake",
        "cuisine": "Dessert",
        "type": "Dessert",
        "ingredients": ["Cream Cheese", "Sugar", "Graham Cracker Crust"],
        "serving": "1 slice",
        "price": 6.00,
        "calories": 500
    },
    {
        "name": "Gumbo",
        "cuisine": "American",
        "type": "Soup",
        "ingredients": ["Shrimp", "Sausage", "Rice", "Okra"],
        "serving": "1 bowl",
        "price": 12.00,
        "calories": 450
    },
    {
        "name": "Roast Beef Sandwich",
        "cuisine": "American",
        "type": "Sandwich",
        "ingredients": ["Roast Beef", "Horseradish", "Bread"],
        "serving": "1 sandwich",
        "price": 8.00,
        "calories": 500
    },
    {
        "name": "Pasta Primavera",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Pasta", "Mixed Vegetables", "Olive Oil"],
        "serving": "1 plate",
        "price": 11.00,
        "calories": 450
    },
    {
        "name": "Potato Gnocchi",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Potatoes", "Flour", "Parmesan"],
        "serving": "1 plate",
        "price": 12.00,
        "calories": 500
    },
    {
        "name": "Apple Pie",
        "cuisine": "American",
        "type": "Dessert",
        "ingredients": ["Apples", "Sugar", "Pie Crust"],
        "serving": "1 slice",
        "price": 5.00,
        "calories": 300
    },
    {
        "name": "Shrimp Risotto",
        "cuisine": "Italian",
        "type": "Main Dish",
        "ingredients": ["Shrimp", "Arborio Rice", "Parmesan"],
        "serving": "1 plate",
        "price": 16.00,
        "calories": 600
    }
]

# %%
menu_items = menu_items_1 + menu_items_2

# Create a new list with ID as the first column
for idx, item in enumerate(menu_items):
    item_with_id = {'id': idx}  # Start IDs from 1
    item_with_id.update(item)  # Add the original item data
    menu_items[idx] = item_with_id  # Replace with new item structure

# %%
# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(menu_items)

# Convert the 'ingredients' list to a string for CSV export
df['ingredients'] = df['ingredients'].apply(lambda x: ', '.join(x))

# %%
df
# Out:
#     id                     name   cuisine       type  \
# 0    0         Margherita Pizza   Italian  Main Dish
# 1    1     Chicken Caesar Salad  American      Salad
# 2    2                 Pad Thai      Thai  Main Dish
# 3    3  Sushi Roll (California)  Japanese  Appetizer
# 4    4             Cheeseburger  American  Main Dish
# ..  ..                      ...       ...        ...
# 95  95      Roast Beef Sandwich  American   Sandwich
# 96  96          Pasta Primavera   Italian  Main Dish
# 97  97           Potato Gnocchi   Italian  Main Dish
# 98  98                Apple Pie  American    Dessert
# 99  99           Shrimp Risotto   Italian  Main Dish
#
#                                     ingredients     serving price  calories
# 0        Dough, Tomato Sauce, Mozzarella, Basil     1 slice  12.0       250
# 1    Romaine Lettuce, Grilled Chicken, Dressing      1 bowl  10.5       400
# 2   Rice Noodles, Shrimp, Peanuts, Bean Sprouts     1 plate  14.0       600
# 3     Sushi Rice, Nori, Crab, Avocado, Cucumber    8 pieces   9.0       300
# 4    Ground Beef, Cheddar, Lettuce, Tomato, Bun    1 burger  11.0       450
# ..                                          ...         ...   ...       ...
# 95               Roast Beef, Horseradish, Bread  1 sandwich   8.0       500
# 96           Pasta, Mixed Vegetables, Olive Oil     1 plate  11.0       450
# 97                    Potatoes, Flour, Parmesan     1 plate  12.0       500
# 98                     Apples, Sugar, Pie Crust     1 slice   5.0       300
# 99               Shrimp, Arborio Rice, Parmesan     1 plate  16.0       600
#
# [100 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'cuisine', 'type', 'ingredients', 'serving', 'price',
#        'calories'],
#       dtype='object')

# %%
# Renaming all columns to snake_case
df = df.drop_duplicates(subset='name')

# %%
df.dtypes
# Out:
# id              int64
# name           object
# cuisine        object
# type           object
# ingredients    object
# serving        object
# price          object
# calories        int64
# dtype: object

# %%
# Export the DataFrame to a new CSV file
df.to_csv('../data/data.csv', index=False)
